# %%
from models.graph_convolutional_neural_network import GCN
from datasets.dataset import KarateClubDataset
import lightning as L

karate_club_dataset = KarateClubDataset()
karate_club_dataset.print_info()
graph_convolutional_neural_network_model = GCN(karate_club_dataset.dataset.num_features, karate_club_dataset.dataset.num_classes)

trainer = L.Trainer(limit_train_batches=100, max_epochs=101)
trainer.fit(model=graph_convolutional_neural_network_model, train_dataloaders=karate_club_dataset.train_dataloader())
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name       | Type             | Params
# ------------------------------------------------
# 0 | conv1      | GCNConv          | 140
# 1 | conv2      | GCNConv          | 20
# 2 | conv3      | GCNConv          | 10
# 3 | classifier | Linear           | 12
# 4 | criterion  | CrossEntropyLoss | 0
# ------------------------------------------------
# 182       Trainable params
# 0         Non-trainable params
# 182       Total params
# 0.001     Total estimated model params size (MB)
# Number of graphs: 1
# Number of features: 34
# Number of classes: 4
# Number of nodes: 34
# Number of edges: 156
# Average node degree: 4.59
# Number of training nodes: 4
# Training node label rate: 0.12
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Number of graphs: 1
# Number of features: 34
# ...
